# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
datos = np.loadtxt("MisDatos.dat")

# %%
x = datos[:,0]
y = datos[:,1]

# %%
fig = plt.figure(figsize=(5,5))
plt.plot(x,y,c='pink')
plt.title('Estimacion de la Derivada Central de $e^{-x^2}$')
plt.show()
